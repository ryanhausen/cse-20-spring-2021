# %% [markdown]
# The slides in this course are adapted from the excellent CSE20 material by Narges Norouzi
#
# See https://cse.slides.com/nargesnorouzi

# %% [markdown]
# # Beginning Programming in Python
#
# ### CSE20 - Spring 2021
#
# Interactive Slides: https://tinyurl.com/cse20-spr21-course-intro

# %% [markdown]
# # About Me
#
# - Ryan Hausen, PhD Candidate in the Computer Science and Egineering Department
# - Research in Computer Vision & Deep Learning applied to Astronomical Imaging
# - Email: rhausen@ucsc.edu

# %% [markdown]
# # Teaching Assistants
#
# - Ishani Chakraborty ischakra@ucsc.edu
# - Vhal Dhimant - Purohit vpurohit@ucsc.edu

# %% [markdown]
# # Instructional Assistants
#
# ### MSI
# Simeon Tran siatran@ucsc.edu
#
# ### ACE
# Andres Aranda aaranda1@ucsc.edu

# %% [markdown]
# # Course Objectives
#
# - Understand fundamentals of programming in Python
# - Understand fundamentals of object-oriented programming
# - Write computer programs to solve specified problems

# %% [markdown]
# # Not Covered
#
# - Other programming languages (Java, C, C++, Matlab, etc.)
# - History of computing
# - Microsoft Office
# - Making a web page (though this can be done with Python ☺)

# %% [markdown]
# # Academic Integrity Policy
#
# - The UCSC Academic Integrity Policy is in effect in this class.
#     -  [Academic Misconduct Policy for Undergraduates](https://ue.ucsc.edu/academic-misconduct.html)
#     - [Policy on Student Conduct and Discipline](https://deanofstudents.ucsc.edu/student-conduct/student-handbook/100.003.pdf)

# %% [markdown]
# # Academic Integrity Policy
#
# - As a student in this class you agree to abide by the following principles:
# - You are not allowed to describe problems on an exam or quiz to a student who has not taken it yet. You are not allowed to show exam contents to another student or view another student's exam contents while working on an exam.
# - No code or solutions are to be distributed to other students either electronically (i.e. e-mail) or on paper.  If you are looking at another student's code (even in the lab), you are in violation of this honor policy.

# %% [markdown]
# # Academic Integrity Policy
#
# - As a student in this class you agree to abide by the following principles:
# - Unless otherwise specified, the only allowed collaboration for the assignments is the discussion of ideas; no collaboration is allowed on the exams and assignments.
# - Unless otherwise noted, exams and individual assignments are pledged: you promise that you have neither given nor received unauthorized help.
# - If you're in doubt regarding an action, you MUST ask before doing it.

# %% [markdown]
# # Anecdote on Cheating
#
# ### This is a class on the fundamentals of programming. The concepts you learn in this class will be used constantly as you program in the future. Having worked with upper division and graduate students it is painfully obvious when someone doesn't have a firm grasp of fundamentals. It will be embarrassing for you to not know.
#
# ### I have structured the course to reward putting in the time, so do it now and be a good programmer.
#
# ### I will run plagiarism checking software on all assignments

# %% [markdown]
# # Letter Grade Policy
#
# |Score | Grade | Score | Grade |
# :-: | :-: | :-: | :-: |
# |$\geq$ 93.0| A | 73.00-76.99 | C |
# |90.00-92.99| A-| 70.00-72.99 | C-|
# |87.00-89.99| B+| 67.00-69.99 | D+|
# |83.00-86.99| B | 60.00-62.99 | D-|
# |77.00-79.99| C+| $\leq$59.99 | F |

# %% [markdown]
# # Grading Policy
#
# |Work | Weighting
# --- | ---
# |5 Assignments|40%|
# |10 Readings/Practices|10%|
# |Attendance|5%|
# |Midterm Exam|20%|
# |Final Exam|25%|

# %% [markdown]
# # Assignments
#
# - Assignments are due bi-weekly and will be submitted to [codePost.io](codePost.io).
# - You should have received invitation email. If you haven't contact me.
# - Assignments are autograded, so you know your grade when you submit
# - You can submit early and as many times as you'd like
# - If you "code for the tests" you will receive a 0.

# %% [markdown]
# # Assignments
# <center>
# <img src="data:image/png;base64,..." />
# </center>

# %% [markdown]
# # Late Assignments
#
# There will be 5 bi-weekly assignments over the course of the quarter. Assignments will involve programming.
# Assignments are usually due every other Sunday at 11:59 PM, and are turned in electronically. Rather than
# approve extensions on a case-by-case basis, each student has 2 "grace days," each of which may be used, no
# explanation necessary, to extend the due date of a (single) assignment by 24 hours. Two grace days cannot be
# used on the same assignment, and half grace days are not permitted. Use your grace days wisely!

# %% [markdown]
# # Textbook
#
# - This course will use zyBooks
# - Sign in/create an account at [learn.zybooks.com](learn.zybooks.com)
# - Enter zyBook code: UCSCCSE20HausenSpring2021
# - Subscribe
#
# A subscription is $34.50. Subscriptions will last until June 24, 2021.
#
# Readings will be tracked via zyBooks and are due weekly.

# %% [markdown]
# # Textbook
#
# ![zybooks](data:image/png;base64,...)

# %% [markdown]
# # Attendance
#
# ### Lecture
#
# Lecture attendance is **mandatory** and will be tracked via zoom, so it is important that you log into zoom using your UCSC account. To receive credit for attendance you need to be at the lecture for at least 80% of the total lecture time. There is no exception to this policy. Lectures will be recorded so you can review them.
#
# ### Labs
#
# Lab attendance is **mandatory** for the first week to ensure that zyBooks, codePost, and Python are all setup correctly. Starting with the second week, attendance is not required but is highly recommended. You can attend any section and they will be recorded.

# %% [markdown]
# # Have a Question?
#
# - Piazza! You likely have similar questions as other people in the class
# - Access Piazza through the course Canvas page
# - You can post privately or anonymously if you don't want other students to see your question
# - You can email me, but there are many more of you than me and so there may be a delay in my reply.
# - If you do email me put CSE20 in the subject

# %% [markdown]
# # Regarding Piazza...
# <center>
# <img src="data:image/jpeg;base64,..."></img>
# </center>

# %% [markdown]
# # Office Hours
#
# - **Ryan**: Mondays 3-5pm by appointment schedule [here](https://calendar.google.com/calendar/selfsched?sstoken=UU1NMVVPeF9TUzZSfGRlZmF1bHR8NTQ5ZGU4NTAwOTQzOGQ1ZjU3MDEzYmYwNTdiMjM2YmU)
# - **Vhal**: Office hours by appointment. Please email me at vpurohit@ucsc.edu with CSE20 OFFICE HOURS APPOINTMENT in the subject (so I don't miss it) and include a short summary of what you want to talk about and what time works for you. If you need help with your code, please also attach the code file you need help with
# - **Ishani**: Hours schedulable via When2Meet, link posted in Piazza.

# %% [markdown]
# # Course Schedule
#
# |   Week   |           Topic           |   Week   |            Topic            |
# |:--------:|:-------------------------:|:--------:|:---------------------------:|
# |   **1**  | Intro/Variables/Operators |  **6**   |       Functions/String      |
# |   **2**  |         Branching         |  **7**   |      Lists/Dictionaries     |
# |   **3**  |           Types           |  **8**   |        Modules/Files        |
# |   **4**  |           Loops           |  **9**   |         Intro to OOP        |
# |   **5**  |     Functions/Midterm     |  **10**  | Supplementary Topics/Review |

# %% [markdown]
# # What's Due Next?
#
# - zyBooks Chapter 1: April 4
# - Assignment 0: April 4

# %% [markdown]
# # Questions?
